# %%
import pandas as pd
# import requests
from bs4 import BeautifulSoup
import re
import os
import time
from random import randint
import xml.etree.ElementTree as et 
import feedparser
import webbrowser
import glob
from collections import defaultdict
from requests_html import HTMLSession
import random
import numpy as np

headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36"}
sleep_time = random.randint(1, 11)

# %%
# !pip install requests-html
def check_file_exists(cik, file):
    if(os.path.exists(file)):
        return True
    return False

# %%
cwd = os.getcwd()

# %% [markdown]
# # Open repository by Company CIK & make details df

# %%
'''
Method that get the cik infomation/data from the SEC website and write them to excel details file per cik
'''

def get_files_details(cik):
    print(f"Started Updating df_details for {cik}")
    requests = HTMLSession()

    page = f'https://www.sec.gov/cgi-bin/browse-edgar?company=&CIK={cik}&type=13F-HR&owner=exclude&count=20' #from 2017

    #request the link to the main page of the HF company and find all files urls
    response1 = requests.get(page,headers=headers)
    soup1 = BeautifulSoup(response1.content.decode(),features='xml')
    HF_urls = soup1.findAll("a",href=True)
    file_urls = [x['href'] for x in HF_urls if 'Archives' in x['href']]
    
    #Check if there are files to download
    if len(file_urls)==0: 
        return False
    
    #Preapare a directory with the name of the cik of the HF company
    directory = f"{cik}"    # Directory
    parent_dir = r"Data"    # Parent Directory path
    path = os.path.join(parent_dir, directory)
    
    #Check if the folder exists if not create it
    if not os.path.exists(path):
        os.makedirs(path)
    
    #Prepare the file header
    df_cols = ["CIK", "main_doc_web_link", "table_doc_web_link", "main_name", "table_name", "Status_main", "Status_table"]
    rows = []

    #prepare the file details path
    df_details_file = f'{path}'+ "\\" + f'{cik}_df_details.csv'
    
    #check if df_details exists
    if os.path.exists(df_details_file):
        #if exists read it
        df_details = pd.read_csv(df_details_file, dtype ={"Status_main":'int', "Status_table":'int'},index_col=0)
    else:
        #create empty one
        df_details = pd.DataFrame(columns = df_cols)

          
    #loop through files links
    for link in file_urls:
        #create a url link
        file_url = 'https://www.sec.gov' + f'{link}'
        
        #request the files
        response2 = requests.get(file_url,headers=headers)       
        soup2 = BeautifulSoup(response2.content.decode(),features='xml')
        urls_xmls = soup2.findAll("a",href=True)

        #get file id name
        xml_primary_doc_name = [x['href'].split("/")[5] for x in urls_xmls if 'Archives' in x['href']][1]
        
        #treate with the primary doc link
        xml_primary_doc_link = [x['href'] for x in urls_xmls if 'Archives' in x['href']][1] 
        main_file = r'{0}\{1}\{2}_main.xml'.format(cwd,path, xml_primary_doc_name)

        #treate with the main table link
        xml_main_table_link = [x['href'] for x in urls_xmls if 'Archives' in x['href']][3]

        #get the cik info to add to df_details file
        main_doc_web_link = f"https://www.sec.gov/{xml_primary_doc_link}"
        table_doc_web_link = f"https://www.sec.gov/{xml_main_table_link}"
        main_name = f"{xml_primary_doc_name}_main.xml" 
        table_name = f"{xml_primary_doc_name}_table.xml" 

        #If filings was exists at df_details skip it else add it df_details
        if main_name in df_details.main_name:
            pass
        
        #new data will be added to df_details
        rows.append({"CIK": cik, "main_doc_web_link": main_doc_web_link, "table_doc_web_link": table_doc_web_link, 
                        "main_name":main_name, "table_name":table_name, "Status_main":1, "Status_table":1})
        
    #update the df_details with the data
    df_details = pd.DataFrame(rows, columns = df_cols)
    
    #export the df_details to file
    df_details.to_csv(f'{path}'+ "\\" + f'{cik}_df_details.csv')
    print(f"Done df_details for {cik}")
   
    return True

# %% [markdown]
# # Download files and check them

# %%
'''
Method that downloads the files & check that they are not corrupted files,
by reading partial fields from the xml fields successfully after download it to the server/pc.
'''
def download_files_and_try_read(cik):
    print(f"Started download_files_and_try_read for {cik}")
    
    #Set the max number of download file tries
    Max_Tries = 5
    
    #Create path to cik files
    path = cwd+r'\Data\{0}'.format(cik)
    df_details_file = path + f'\\{cik}_df_details.csv'    
    
    #Check if the df_details file exists
    if os.path.exists(df_details_file) == False:
        print('df_details is missing')
        return False
    
    #if df_details file exists read it
    df_details = pd.read_csv(df_details_file, dtype ={"Status_main":'int', "Status_table":'int'},index_col=0)
    
    #loop over all the information that exists at the df_details file
    for i in range(0,len(df_details)):
        '''
        main file
        '''
        #treat with the main doc web link 
        if df_details.loc[i, "Status_main"] > 0:
            main_file_name = df_details['main_name'][i]
            main_file_link = df_details['main_doc_web_link'][i]
            main_file = path + "\\" + main_file_name
            
            a=df_details.loc[i, "Status_main"]
            while a < Max_Tries:
                try:
                    #if os.path.exists(main_file): no need to check and throw exception
                    #if the file not exist start first download
                    in_main_file = open(main_file,"r")
                    contents = in_main_file.read()
                    soup = BeautifulSoup(contents,'xml') 
                    #if the file exists read the xml nodes
                    period = soup.find("periodOfReport").get_text()
                    #if the file exists and it is in correct format, update the parameters to exit from the while loop
                    a = Max_Tries
                    #update the Status_main at the df details to 0 (Success & in Correct format file)
                    df_details.loc[i, "Status_main"] = 0
                    #print success message
                    #print("main file success ", main_file_name)                    
                except:
                    #if file not exist or the file downloaded corrupted try to download it again till you reach the max tries
                    if a < Max_Tries:
                        #open session
                        requests = HTMLSession()
                        #request the url
                        download_xml_main = requests.get(f'{main_file_link}')
                        #open a write socket to write the requested result to a file
                        with open(main_file, 'w+b') as file:
                            #write the data to the file
                            file.write(download_xml_main.content)
                    #if we reach the maximum tries and we still didn't success to download the file in correct format
                    if a==Max_Tries:
                        #write an error message
                        print(f"error reading main file {main_file_name}")
                    #update the tries data
                    a+=1
                    df_details.loc[i, "Status_main"] +=1
                    
        '''
        table file (the same logic like main file)
        '''
        if df_details.loc[i, "Status_table"] > 0:
            table_file_name = df_details['table_name'][i]
            table_file_link = df_details['table_doc_web_link'][i]
            table_file = path + "\\" + table_file_name
            b=df_details.loc[i, "Status_table"]
            while b < Max_Tries:
                try:
                    #check if file exists
                    #if os.path.exists(table_file):
                    in_table_file = open(table_file,"r")
                    table_content = in_table_file.read()
                    soup = BeautifulSoup(table_content,'xml')                                
                    nameOfIssuers = soup.find_all('nameOfIssuer')
                    #print(nameOfIssuers)
                    for j in nameOfIssuers:
                        nameOfIssuer = str.rstrip(j.get_text())
                        #print(nameOfIssuer)
                        #print("table file success ",table_file_name)
                    b=Max_Tries
                    df_details.loc[i, "Status_table"] = 0

                except:          
                    if b < Max_Tries:
                        requests = HTMLSession()
                        xml_main_table = requests.get(f'{table_file_link}') #
                        with open(table_file, 'w+b') as file:
                            file.write(xml_main_table.content)
                    
                    if b == Max_Tries:
                        print(f"error reading table file {table_file_name}")
                    
                    b+=1
                    df_details.loc[i, "Status_table"] += 1
    
    
    df_details.to_csv(df_details_file)
    sum_status = sum(df_details["Status_main"]) + sum(df_details["Status_table"])
    print(f"Done second download {cik}, sum_status is {sum_status}")

    return True

# %% [markdown]
# # Build df by CIK

# %%
'''
Method that read the data from the Xml files and create DF with the CIKs data
'''
def from_cik_files_to_df(cik):
    '''
    Read files by df_details
    '''
    path = cwd+r'\Data\{0}'.format(cik)
    df_details_file = path + f'\\{cik}_df_details.csv'
    df_details = pd.read_csv(df_details_file, dtype ={"Status_main":'int', "Status_table":'int'},index_col=0)
    
    df_cols = ["CIK", "vc_name", "vc_country", "periodOfReport", "nameOfIssuer", "titleOfClass", "cusip", "value", 
               "sshPrnamt"]
    rows = []
    
    #Re-validate that the files are readable
    sum_status = sum(df_details["Status_main"]) + sum(df_details["Status_table"])
    
    if sum_status ==0:
        #loop through each file that exist at df_details and collect the data
        for i in range(len(df_details)):
            
            '''
            main file
            '''
            main_file_name = df_details['main_name'][i]
            main_file_link = df_details['main_doc_web_link'][i]
            main_file = path + "\\" + main_file_name
            in_main_file = open(main_file,"r")

            contents = in_main_file.read()
            soup = BeautifulSoup(contents,'xml')
            CIK = soup.find("cik").get_text()
            vc_name = soup.find("name").get_text()
            vc_country = soup.find("stateOrCountry").get_text()
            periodOfReport = soup.find("periodOfReport").get_text()

            '''
            table file 
            '''
            table_file_name = df_details['table_name'][i]
            table_file = path + "\\" + table_file_name 
            in_table_file = open(table_file,"r")
            table_content = in_table_file.read().replace('\n','').replace(' ','')
            soup = BeautifulSoup(table_content,'xml')

            try:     
                nameOfIssuers = soup.find_all('nameOfIssuer')
                titleOfClasss = soup.find_all('titleOfClass')
                cusips = soup.find_all('cusip')
                values = soup.find_all('value')
                shrsOrPrnAmts = soup.find_all('shrsOrPrnAmt')
                sshPrnamts = soup.find_all('sshPrnamt')

                for i in range(len(nameOfIssuers)):  
                    nameOfIssuer = str.rstrip(nameOfIssuers[i].get_text())
                    titleOfClass = str.rstrip(titleOfClasss[i].get_text())
                    cusip = str.rstrip(cusips[i].get_text())
                    value = str.rstrip(values[i].get_text())
                    shrsOrPrnAmt = str.rstrip(shrsOrPrnAmts[i].get_text())
                    sshPrnamt = str.rstrip(sshPrnamts[i].get_text())
                    #Collect the data from the files
                    rows.append({"CIK": cik, "vc_name": vc_name, "vc_country": vc_country, "periodOfReport": periodOfReport,
                         "nameOfIssuer": nameOfIssuer, "titleOfClass": titleOfClass, "cusip": cusip, "value": value, 
                          "sshPrnamt":sshPrnamt, "shrsOrPrnAmt":shrsOrPrnAmt})

            except:
                print("problem with ",table_file_name)
                pass

        '''
        Save the data to df_HF.csv
        '''
        out_df = pd.DataFrame(rows, columns = df_cols)
        out_df[['value', 'sshPrnamt']] = out_df[['value', 'sshPrnamt']].astype('float')
        out_df.periodOfReport = pd.to_datetime(out_df.periodOfReport)
        out_df.to_csv(f'{path}\\{cik}_df_HF.csv')
        
        return True
    
    else:
        return False

# %% [markdown]
# # Build DF by stocks from the data that was collected at the DF_HF

# %%
def create_stocks_df(cik):
    if(check_if_stock_file_exists(cik)):
        return True
    path = cwd+f'\\Data\\{cik}'
    stock_cik_df = path + f'\\{cik}_stocks_df.csv'

    initial_df_file = path + f'\\{cik}_df_HF.csv'
    
    initial_df = pd.read_csv(initial_df_file, index_col=0)
    
    """
    create list of dates
    """
    periodOfReports = initial_df.periodOfReport.value_counts().sort_index().reset_index().rename(columns={'index': 'report_date',
                                                                                                          'periodOfReport': 'count_date'})
    
    """
    find unique stock names
    """
    nameOfIssuers = initial_df.nameOfIssuer.unique()
    
    """
    create stock df
    """
    
    stocks_df = pd.DataFrame()
    
    for name in nameOfIssuers:
        """
        slice df
        """
        small_df = initial_df.loc[initial_df.nameOfIssuer == name]
        titleOfClasses = small_df.titleOfClass.unique()
        
        for title in titleOfClasses:
            new_small_df = small_df.loc[small_df.titleOfClass == title]

            """
            add missing dates
            """
            small_df_with_dates = periodOfReports.merge(new_small_df, left_on='report_date',
                                                        right_on='periodOfReport', 
                                                        how='left').drop(['count_date', 'periodOfReport'], axis=1)

            """
            fill nan with 0
            """
            small_df_with_dates = small_df_with_dates.fillna(0)

            """
            fill repeat values
            """
            columns = ['CIK', 'vc_name', 'vc_country', 'nameOfIssuer', 'titleOfClass', 'cusip']
            fill_values_dict = {}
            for column in columns:
                for value in small_df_with_dates[column]:
                    if value != 0:
                        fill_values_dict[column] = value
            for column in columns:
                for i, value in enumerate(small_df_with_dates[column]):
                    if value == 0:
                        small_df_with_dates.loc[i, column] = fill_values_dict[column]

            """
            add the new columns
            """
            new_columns = ['PPS', 'holding_duration', 'holding_proportion', 'portfolio_duration', 'New', 'AddedTo', 
                           'Trimmed', 'SoldOut', 'Profit', 'yield_from_last_report', 'yield_from_1_year', 
                           'yield_from_3_year', 'yield_from_continuous_profit']
            for column in new_columns:
                small_df_with_dates[column] = 0

            for i in range(len(small_df_with_dates)):
                """
                PPS
                """
                if small_df_with_dates.loc[i, 'sshPrnamt'] != 0:
                    small_df_with_dates.loc[i, 'PPS'] = round((small_df_with_dates.loc[i, 'value'] * 1000) / small_df_with_dates.loc[i, 'sshPrnamt'], 2)

                """
                duration
                """
                if small_df_with_dates.loc[i, 'value'] == 0:
                    small_df_with_dates.loc[i, 'holding_duration'] = 0
                else:
                    q_duration = 1
                    j = i-1
                    while j > -1:
                        if small_df_with_dates.loc[j, 'value'] != 0:
                            q_duration += 1
                            j -= 1
                        else:
                            break
                    small_df_with_dates.loc[i, 'holding_duration'] = q_duration/4


            """
            stock holding changes
            """
            for i in range(1, len(small_df_with_dates)):
                if small_df_with_dates.loc[i, 'value'] != 0 and small_df_with_dates.loc[i-1, 'value'] == 0:
                    small_df_with_dates.loc[i, 'New'] = small_df_with_dates.loc[i, 'value']
                elif small_df_with_dates.loc[i-1, 'value'] != 0 and small_df_with_dates.loc[i, 'value'] == 0:
                    small_df_with_dates.loc[i, 'SoldOut'] = small_df_with_dates.loc[i-1, 'value']
                elif small_df_with_dates.loc[i, 'value'] != 0 and small_df_with_dates.loc[i-1, 'value'] != 0:
                    gap = small_df_with_dates.loc[i, 'sshPrnamt'] - small_df_with_dates.loc[i-1, 'sshPrnamt']
                    if gap < 0:
                        small_df_with_dates.loc[i, 'Trimmed'] = round((((small_df_with_dates.loc[i, 'PPS'] + small_df_with_dates.loc[i-1, 'PPS'])/2) * (gap * (-1)))/1000, 2)
                    elif gap > 0:
                        small_df_with_dates.loc[i, 'AddedTo'] = round((((small_df_with_dates.loc[i, 'PPS'] + small_df_with_dates.loc[i-1, 'PPS'])/2) * gap) /1000, 2)
                if small_df_with_dates.loc[i, 'value'] != 0:
                    small_df_with_dates.loc[i, 'Profit'] = round(small_df_with_dates.loc[i, 'value'] - small_df_with_dates.loc[i, 'New'] - small_df_with_dates.loc[i, 'AddedTo'] + small_df_with_dates.loc[i, 'SoldOut'] + small_df_with_dates.loc[i, 'Trimmed']- small_df_with_dates.loc[i-1, 'value'], 2)
                if small_df_with_dates.loc[i-1, 'value'] != 0:
                    small_df_with_dates.loc[i, 'yield_from_last_report'] = round(small_df_with_dates.loc[i, 'Profit'] / small_df_with_dates.loc[i-1, 'value'], 2)

            """
            stock Yield
            """
            year_profit = 0
            quarters = len(small_df_with_dates)-1 
            while quarters >= len(small_df_with_dates)-5:
                year_profit += small_df_with_dates.loc[quarters, 'Profit']
                quarters -= 1
            if small_df_with_dates.loc[len(small_df_with_dates)-1, 'Profit'] != 0 and small_df_with_dates.loc[len(small_df_with_dates)-5, 'Profit'] != 0:
                small_df_with_dates.loc[len(small_df_with_dates)-1, 'yield_from_1_year'] = round(year_profit/small_df_with_dates.loc[len(small_df_with_dates)-5, 'value'], 2)


            three_year_profit = 0
            calculate_continuous_profit = 0
            quarters = len(small_df_with_dates)-1
            if quarters > 13 and small_df_with_dates.loc[len(small_df_with_dates)-13, 'Profit'] != 0:
                while quarters >= len(small_df_with_dates)-13:
                    three_year_profit += small_df_with_dates.loc[quarters, 'Profit']
                    quarters -= 1
                if small_df_with_dates.loc[len(small_df_with_dates)-1, 'Profit'] != 0:
                    small_df_with_dates.loc[len(small_df_with_dates)-1, 'yield_from_3_year'] = round(three_year_profit/small_df_with_dates.loc[len(small_df_with_dates)-13, 'value'], 2)
            else:
                while quarters >= 0:
                    if small_df_with_dates.loc[quarters, 'Profit'] != 0:
                        calculate_continuous_profit += small_df_with_dates.loc[quarters, 'Profit']
                        quarters -= 1
                    else:
                        break
                if small_df_with_dates.loc[len(small_df_with_dates)-1, 'Profit'] != 0 and small_df_with_dates.loc[quarters+1, 'Profit'] != 0:
                    small_df_with_dates.loc[len(small_df_with_dates)-1, 'yield_from_continuous_profit'] = round(calculate_continuous_profit/small_df_with_dates.loc[quarters+1, 'value'], 2)

            """
            create stocks_df
            """
            stocks_df = pd.concat([stocks_df, small_df_with_dates], ignore_index=True)

    stocks_df['holding_proportion'] = round(stocks_df.value / stocks_df.groupby('report_date')['value'].transform('sum'), 4)
    stocks_df['portfolio_duration'] = round(stocks_df['holding_proportion']*stocks_df['holding_duration'],2)
    stocks_df['bought_times'] = np.where(stocks_df.New + stocks_df.AddedTo > 0, 1, 0)

    """
    stocks_df to file
    """
    stocks_df.to_csv(path + f'\\{cik}_stocks_df.csv')
    
    return True

# %%
def check_if_stock_file_exists(cik):
    path = cwd+f'\\Data\\{cik}'
    stock_cik_df_path = path + f'\\{cik}_stocks_df.csv'
    if(os.path.exists(stock_cik_df_path)):
        return True
    return False

# %%
cik_df = pd.read_excel("CIK-list.xlsx")
cik_list = [str(x) for x in cik_df["CIK"]]

# %%
#list that points to ciks that have corrupted files or unfinneshed cik file download process
error_list=[]
CIK_Done=[]

# %%
'''
Both invokes below are for the same purpose to create the stocks files they also call the same function
This first one do all the job, the second one check if the stock file of the CIK is missing then do the job
we Can run one of them and will got the same results.
'''

# %%
# %%time
for CIK in cik_list: 
    print("Started working on ",CIK)
    
    try: 
        if get_files_details(CIK) is True:
            if download_files_and_try_read(CIK) is True: 
                if from_cik_files_to_df(CIK) is True: 
                    print(f"formed successfully {CIK}_df_HF")
                    
                    if create_stocks_df(CIK) is True:
                        print(f"formed successfully {CIK}_df_Stocks")
                    else:
                        print(f"failed to create {CIK}_df_Stocks")
                        error_list.append(CIK)
                        
                else:
                    print(CIK, "Couldn't create df_HF file")
                    error_list.append(CIK)
                    
            else:
                error_list.append(CIK)
                print("Incorrupt files were detected at ",CIK)
                print("#####################\n ")
        
        else:
            error_list.append(CIK)
            print(CIK, "doesn't have 13F files")
            
        print("\nFinished working on ",CIK)
        print("#####################\n ")

    except:
        print("couldn't work with ",CIK)
        error_list.append(CIK)
        print("#####################\n ")
        pass
# Out:
# Started working on  1539436
# Started Updating df_details for 1539436
# Done df_details for 1539436
# Started download_files_and_try_read for 1539436
# Done second download 1539436, sum_status is 0
# formed successfully 1539436_df_HF
# formed successfully 1539436_df_Stocks
#
# Finished working on  1539436
# #####################
#
# Started working on  1358706
# Started Updating df_details for 1358706
# Done df_details for 1358706
# Started download_files_and_try_read for 1358706
# Done second download 1358706, sum_status is 0
# formed successfully 1358706_df_HF
# formed successfully 1358706_df_Stocks
#
# Finished working on  1358706
# #####################
#
# Started working on  916542
# Started Updating df_details for 916542
# Done df_details for 916542
# Started download_files_and_try_read for 916542
# Done second download 916542, sum_status is 0
# formed successfully 916542_df_HF
# formed successfully 916542_df_Stocks
#
# Finished working on  916542
# #####################
#
# Started working on  1165408
# Started Updating df_details for 1165408
# Done df_details for 1165408
# Started download_files_and_try_read for 1165408
# Done second download 1165408, sum_status is 0
# formed successfully 1165408_df_HF
# formed successfully 1165408_df_Stocks
#
# Finished working on  1165408
# #####################
#
# Started working on  1097278
# Started Updating df_details for 1097278
# Done df_details for 1097278
# Started download_files_and_try_read for 1097278
# Done second download 1097278, sum_status is 0
# formed successfully 1097278_df_HF
# formed successfully 1097278_df_Stocks
#
# Finished working on  1097278
# #####################
#
# Started working on  1112520
# Started Updating df_details for 1112520
# Done df_details for 1112520
# Started download_files_and_try_read for 1112520
# Done second download 1112520, sum_status is 0
# formed successfully 1112520_df_HF
# formed successfully 1112520_df_Stocks
#
# Finished working on  1112520
# #####################
#
# Started working on  1230239
# Started Updating df_details for 1230239
# Done df_details for 1230239
# Started download_files_and_try_read for 1230239
# Done second download 1230239, sum_status is 0
# formed successfully 1230239_df_HF
# formed successfully 1230239_df_Stocks
#
# Finished working on  1230239
# #####################
#
# Started working on  1326234
# Started Updating df_details for 1326234
# Done df_details for 1326234
# Started download_files_and_try_read for 1326234
# Done second download 1326234, sum_status is 0
# formed successfully 1326234_df_HF
# formed successfully 1326234_df_Stocks
#
# Finished working on  1326234
# #####################
#
# Started working on  1109448
# Started Updating df_details for 1109448
# Done df_details for 1109448
# Started download_files_and_try_read for 1109448
# Done second download 1109448, sum_status is 0
# formed successfully 1109448_df_HF
# formed successfully 1109448_df_Stocks
#
# Finished working on  1109448
# #####################
#
# Started working on  1396835
# Started Updating df_details for 1396835
# Done df_details for 1396835
# Started download_files_and_try_read for 1396835
# Done second download 1396835, sum_status is 0
# formed successfully 1396835_df_HF
# formed successfully 1396835_df_Stocks
#
# Finished working on  1396835
# #####################
#
# Started working on  1541617
# Started Updating df_details for 1541617
# Done df_details for 1541617
# Started download_files_and_try_read for 1541617
# Done second download 1541617, sum_status is 0
# formed successfully 1541617_df_HF
# formed successfully 1541617_df_Stocks
#
# Finished working on  1541617
# #####################
#
# Started working on  1453072
# Started Updating df_details for 1453072
# Done df_details for 1453072
# Started download_files_and_try_read for 1453072
# Done second download 1453072, sum_status is 0
# formed successfully 1453072_df_HF
# formed successfully 1453072_df_Stocks
#
# Finished working on  1453072
# #####################
#
# Started working on  1102598
# Started Updating df_details for 1102598
# Done df_details for 1102598
# Started download_files_and_try_read for 1102598
# Done second download 1102598, sum_status is 0
# formed successfully 1102598_df_HF
# formed successfully 1102598_df_Stocks
#
# Finished working on  1102598
# #####################
#
# Started working on  1446114
# Started Updating df_details for 1446114
# Done df_details for 1446114
# Started download_files_and_try_read for 1446114
# Done second download 1446114, sum_status is 0
# formed successfully 1446114_df_HF
# formed successfully 1446114_df_Stocks
#
# Finished working on  1446114
# #####################
#
# Started working on  1323255
# Started Updating df_details for 1323255
# Done df_details for 1323255
# Started download_files_and_try_read for 1323255
# Done second download 1323255, sum_status is 0
# formed successfully 1323255_df_HF
# formed successfully 1323255_df_Stocks
#
# Finished working on  1323255
# #####################
#
# Started working on  1656456
# Started Updating df_details for 1656456
# Done df_details for 1656456
# Started download_files_and_try_read for 1656456
# Done second download 1656456, sum_status is 0
# formed successfully 1656456_df_HF
# formed successfully 1656456_df_Stocks
#
# Finished working on  1656456
# #####################
#
# Started working on  1167557
# Started Updating df_details for 1167557
# Done df_details for 1167557
# Started download_files_and_try_read for 1167557
# Done second download 1167557, sum_status is 0
# formed successfully 1167557_df_HF
# formed successfully 1167557_df_Stocks
#
# Finished working on  1167557
# #####################
#
# Started working on  1608108
# Started Updating df_details for 1608108
# Done df_details for 1608108
# Started download_files_and_try_read for 1608108
# Done second download 1608108, sum_status is 0
# formed successfully 1608108_df_HF
# formed successfully 1608108_df_Stocks
#
# Finished working on  1608108
# #####################
#
# Started working on  936753
# Started Updating df_details for 936753
# Done df_details for 936753
# Started download_files_and_try_read for 936753
# Done second download 936753, sum_status is 0
# formed successfully 936753_df_HF
# formed successfully 936753_df_Stocks
#
# Finished working on  936753
# #####################
#
# Started working on  1080171
# Started Updating df_details for 1080171
# Done df_details for 1080171
# Started download_files_and_try_read for 1080171
# Done second download 1080171, sum_status is 0
# formed successfully 1080171_df_HF
# formed successfully 1080171_df_Stocks
#
# Finished working on  1080171
# #####################
#
# Started working on  860644
# Started Updating df_details for 860644
# Done df_details for 860644
# Started download_files_and_try_read for 860644
# Done second download 860644, sum_status is 0
# formed successfully 860644_df_HF
# formed successfully 860644_df_Stocks
#
# Finished working on  860644
# #####################
#
# Started working on  1697748
# Started Updating df_details for 1697748
# Done df_details for 1697748
# Started download_files_and_try_read for 1697748
# Done second download 1697748, sum_status is 0
# formed successfully 1697748_df_HF
# formed successfully 1697748_df_Stocks
#
# Finished working on  1697748
# #####################
#
# Started working on  1601086
# Started Updating df_details for 1601086
# Done df_details for 1601086
# Started download_files_and_try_read for 1601086
# Done second download 1601086, sum_status is 0
# formed successfully 1601086_df_HF
# formed successfully 1601086_df_Stocks
#
# Finished working on  1601086
# #####################
#
# Started working on  1483859
# Started Updating df_details for 1483859
# Done df_details for 1483859
# Started download_files_and_try_read for 1483859
# Done second download 1483859, sum_status is 0
# formed successfully 1483859_df_HF
# formed successfully 1483859_df_Stocks
#
# Finished working on  1483859
# #####################
#
# Started working on  1164508
# Started Updating df_details for 1164508
# Done df_details for 1164508
# Started download_files_and_try_read for 1164508
# Done second download 1164508, sum_status is 0
# formed successfully 1164508_df_HF
# formed successfully 1164508_df_Stocks
#
# Finished working on  1164508
# #####################
#
# Started working on  1466153
# Started Updating df_details for 1466153
# Done df_details for 1466153
# Started download_files_and_try_read for 1466153
# Done second download 1466153, sum_status is 0
# formed successfully 1466153_df_HF
# formed successfully 1466153_df_Stocks
#
# Finished working on  1466153
# #####################
#
# Started working on  700529
# Started Updating df_details for 700529
# Done df_details for 700529
# Started download_files_and_try_read for 700529
# Done second download 700529, sum_status is 0
# formed successfully 700529_df_HF
# formed successfully 700529_df_Stocks
#
# Finished working on  700529
# #####################
#
# Started working on  1730574
# Started Updating df_details for 1730574
# Done df_details for 1730574
# Started download_files_and_try_read for 1730574
# Done second download 1730574, sum_status is 0
# formed successfully 1730574_df_HF
# formed successfully 1730574_df_Stocks
#
# Finished working on  1730574
# #####################
#
# Started working on  1027817
# Started Updating df_details for 1027817
# Done df_details for 1027817
# Started download_files_and_try_read for 1027817
# Done second download 1027817, sum_status is 0
# formed successfully 1027817_df_HF
# formed successfully 1027817_df_Stocks
#
# Finished working on  1027817
# #####################
#
# Started working on  1777813
# Started Updating df_details for 1777813
# Done df_details for 1777813
# Started download_files_and_try_read for 1777813
# Done second download 1777813, sum_status is 0
# formed successfully 1777813_df_HF
# formed successfully 1777813_df_Stocks
#
# Finished working on  1777813
# #####################
#
# Started working on  1221362
# Started Updating df_details for 1221362
# Done df_details for 1221362
# Started download_files_and_try_read for 1221362
# Done second download 1221362, sum_status is 0
# couldn't work with  1221362
# #####################
#
# Started working on  1791827
# Started Updating df_details for 1791827
# Done df_details for 1791827
# Started download_files_and_try_read for 1791827
# Done second download 1791827, sum_status is 0
# formed successfully 1791827_df_HF
# formed successfully 1791827_df_Stocks
#
# Finished working on  1791827
# #####################
#
# Started working on  1633313
# Started Updating df_details for 1633313
# Done df_details for 1633313
# Started download_files_and_try_read for 1633313
# Done second download 1633313, sum_status is 0
# formed successfully 1633313_df_HF
# formed successfully 1633313_df_Stocks
#
# Finished working on  1633313
# #####################
#
# Started working on  1109147
# Started Updating df_details for 1109147
# Done df_details for 1109147
# Started download_files_and_try_read for 1109147
# Done second download 1109147, sum_status is 0
# formed successfully 1109147_df_HF
# formed successfully 1109147_df_Stocks
#
# Finished working on  1109147
# #####################
#
# Started working on  1263508
# Started Updating df_details for 1263508
# Done df_details for 1263508
# Started download_files_and_try_read for 1263508
# Done second download 1263508, sum_status is 0
# formed successfully 1263508_df_HF
# formed successfully 1263508_df_Stocks
#
# Finished working on  1263508
# #####################
#
# Started working on  1218710
# Started Updating df_details for 1218710
# Done df_details for 1218710
# Started download_files_and_try_read for 1218710
# Done second download 1218710, sum_status is 0
# formed successfully 1218710_df_HF
# formed successfully 1218710_df_Stocks
#
# Finished working on  1218710
# #####################
#
# Started working on  1340807
# Started Updating df_details for 1340807
# Done df_details for 1340807
# Started download_files_and_try_read for 1340807
# Done second download 1340807, sum_status is 0
# formed successfully 1340807_df_HF
# formed successfully 1340807_df_Stocks
#
# Finished working on  1340807
# #####################
#
# Started working on  9015
# Started Updating df_details for 9015
# Done df_details for 9015
# Started download_files_and_try_read for 9015
# Done second download 9015, sum_status is 0
# formed successfully 9015_df_HF
# formed successfully 9015_df_Stocks
#
# Finished working on  9015
# #####################
#
# Started working on  313028
# Started Updating df_details for 313028
# Done df_details for 313028
# Started download_files_and_try_read for 313028
# Done second download 313028, sum_status is 0
# formed successfully 313028_df_HF
# formed successfully 313028_df_Stocks
#
# Finished working on  313028
# #####################
#
# Started working on  1061768
# Started Updating df_details for 1061768
# Done df_details for 1061768
# Started download_files_and_try_read for 1061768
# Done second download 1061768, sum_status is 0
# formed successfully 1061768_df_HF
# formed successfully 1061768_df_Stocks
#
# Finished working on  1061768
# #####################
#
# Started working on  1711889
# Started Updating df_details for 1711889
# Done df_details for 1711889
# Started download_files_and_try_read for 1711889
# Done second download 1711889, sum_status is 0
# formed successfully 1711889_df_HF
# formed successfully 1711889_df_Stocks
#
# Finished working on  1711889
# #####################
#
# Started working on  12518
# Started Updating df_details for 12518
# 12518 doesn't have 13F files
#
# Finished working on  12518
# #####################
#
# Started working on  1610880
# Started Updating df_details for 1610880
# Done df_details for 1610880
# Started download_files_and_try_read for 1610880
# Done second download 1610880, sum_status is 0
# formed successfully 1610880_df_HF
# formed successfully 1610880_df_Stocks
#
# Finished working on  1610880
# #####################
#
# Started working on  1600285
# Started Updating df_details for 1600285
# Done df_details for 1600285
# Started download_files_and_try_read for 1600285
# Done second download 1600285, sum_status is 0
# formed successfully 1600285_df_HF
# formed successfully 1600285_df_Stocks
#
# Finished working on  1600285
# #####################
#
# Started working on  1386060
# Started Updating df_details for 1386060
# Done df_details for 1386060
# Started download_files_and_try_read for 1386060
# Done second download 1386060, sum_status is 0
# formed successfully 1386060_df_HF
# formed successfully 1386060_df_Stocks
#
# Finished working on  1386060
# #####################
#
# Started working on  1015086
# Started Updating df_details for 1015086
# Done df_details for 1015086
# Started download_files_and_try_read for 1015086
# Done second download 1015086, sum_status is 0
# formed successfully 1015086_df_HF
# formed successfully 1015086_df_Stocks
#
# Finished working on  1015086
# #####################
#
# Started working on  829108
# Started Updating df_details for 829108
# Done df_details for 829108
# Started download_files_and_try_read for 829108
# Done second download 829108, sum_status is 0
# formed successfully 829108_df_HF
# formed successfully 829108_df_Stocks
#
# Finished working on  829108
# #####################
#
# Started working on  1350694
# Started Updating df_details for 1350694
# Done df_details for 1350694
# Started download_files_and_try_read for 1350694
# Done second download 1350694, sum_status is 0
# formed successfully 1350694_df_HF
# formed successfully 1350694_df_Stocks
#
# Finished working on  1350694
# #####################
#
# Started working on  1001085
# Started Updating df_details for 1001085
# Done df_details for 1001085
# Started download_files_and_try_read for 1001085
# Done second download 1001085, sum_status is 0
# formed successfully 1001085_df_HF
# formed successfully 1001085_df_Stocks
#
# Finished working on  1001085
# #####################
#
# Started working on  1315868
# Started Updating df_details for 1315868
# Done df_details for 1315868
# Started download_files_and_try_read for 1315868
# Done second download 1315868, sum_status is 0
# formed successfully 1315868_df_HF
# formed successfully 1315868_df_Stocks
#
# Finished working on  1315868
# #####################
#
# Started working on  1802881
# Started Updating df_details for 1802881
# Done df_details for 1802881
# Started download_files_and_try_read for 1802881
# Done second download 1802881, sum_status is 0
# formed successfully 1802881_df_HF
# formed successfully 1802881_df_Stocks
#
# Finished working on  1802881
# #####################
#
# Started working on  1316507
# Started Updating df_details for 1316507
# Done df_details for 1316507
# Started download_files_and_try_read for 1316507
# Done second download 1316507, sum_status is 0
# formed successfully 1316507_df_HF
# formed successfully 1316507_df_Stocks
#
# Finished working on  1316507
# #####################
#
# Started working on  1352924
# Started Updating df_details for 1352924
# Done df_details for 1352924
# Started download_files_and_try_read for 1352924
# Done second download 1352924, sum_status is 0
# formed successfully 1352924_df_HF
# formed successfully 1352924_df_Stocks
#
# Finished working on  1352924
# #####################
#
# Started working on  1789779
# Started Updating df_details for 1789779
# Done df_details for 1789779
# Started download_files_and_try_read for 1789779
# Done second download 1789779, sum_status is 0
# formed successfully 1789779_df_HF
# formed successfully 1789779_df_Stocks
#
# Finished working on  1789779
# #####################
#
# Started working on  1537014
# Started Updating df_details for 1537014
# Done df_details for 1537014
# Started download_files_and_try_read for 1537014
# Done second download 1537014, sum_status is 0
# formed successfully 1537014_df_HF
# formed successfully 1537014_df_Stocks
#
# Finished working on  1537014
# #####################
#
# Started working on  1279936
# Started Updating df_details for 1279936
# Done df_details for 1279936
# Started download_files_and_try_read for 1279936
# Done second download 1279936, sum_status is 0
# formed successfully 1279936_df_HF
# formed successfully 1279936_df_Stocks
#
# Finished working on  1279936
# #####################
#
# Started working on  1323645
# Started Updating df_details for 1323645
# Done df_details for 1323645
# Started download_files_and_try_read for 1323645
# Done second download 1323645, sum_status is 0
# formed successfully 1323645_df_HF
# formed successfully 1323645_df_Stocks
#
# Finished working on  1323645
# #####################
#
# Started working on  895213
# Started Updating df_details for 895213
# Done df_details for 895213
# Started download_files_and_try_read for 895213
# Done second download 895213, sum_status is 0
# formed successfully 895213_df_HF
# formed successfully 895213_df_Stocks
#
# Finished working on  895213
# #####################
#
# Started working on  1426196
# Started Updating df_details for 1426196
# Done df_details for 1426196
# Started download_files_and_try_read for 1426196
# Done second download 1426196, sum_status is 0
# formed successfully 1426196_df_HF
# formed successfully 1426196_df_Stocks
#
# Finished working on  1426196
# #####################
#
# Started working on  1706766
# Started Updating df_details for 1706766
# Done df_details for 1706766
# Started download_files_and_try_read for 1706766
# Done second download 1706766, sum_status is 0
# formed successfully 1706766_df_HF
# formed successfully 1706766_df_Stocks
#
# Finished working on  1706766
# #####################
#
# Started working on  1033984
# Started Updating df_details for 1033984
# Done df_details for 1033984
# Started download_files_and_try_read for 1033984
# Done second download 1033984, sum_status is 0
# formed successfully 1033984_df_HF
# formed successfully 1033984_df_Stocks
#
# Finished working on  1033984
# #####################
#
# Started working on  1525907
# Started Updating df_details for 1525907
# Done df_details for 1525907
# Started download_files_and_try_read for 1525907
# Done second download 1525907, sum_status is 0
# formed successfully 1525907_df_HF
# couldn't work with  1525907
# #####################
#
# Started working on  1332632
# Started Updating df_details for 1332632
# Done df_details for 1332632
# Started download_files_and_try_read for 1332632
# Done second download 1332632, sum_status is 0
# formed successfully 1332632_df_HF
# formed successfully 1332632_df_Stocks
#
# Finished working on  1332632
# #####################
#
# Started working on  1094749
# Started Updating df_details for 1094749
# Done df_details for 1094749
# Started download_files_and_try_read for 1094749
# Done second download 1094749, sum_status is 0
# formed successfully 1094749_df_HF
# formed successfully 1094749_df_Stocks
#
# Finished working on  1094749
# #####################
#
# Started working on  1423053
# Started Updating df_details for 1423053
# Done df_details for 1423053
# Started download_files_and_try_read for 1423053
# Done second download 1423053, sum_status is 0
# formed successfully 1423053_df_HF
# formed successfully 1423053_df_Stocks
#
# Finished working on  1423053
# #####################
#
# Started working on  1348883
# Started Updating df_details for 1348883
# Done df_details for 1348883
# Started download_files_and_try_read for 1348883
# Done second download 1348883, sum_status is 0
# formed successfully 1348883_df_HF
# formed successfully 1348883_df_Stocks
#
# Finished working on  1348883
# #####################
#
# Started working on  1135730
# Started Updating df_details for 1135730
# Done df_details for 1135730
# Started download_files_and_try_read for 1135730
# Done second download 1135730, sum_status is 0
# formed successfully 1135730_df_HF
# formed successfully 1135730_df_Stocks
#
# Finished working on  1135730
# #####################
#
# Started working on  1080628
# Started Updating df_details for 1080628
# Done df_details for 1080628
# Started download_files_and_try_read for 1080628
# Done second download 1080628, sum_status is 0
# formed successfully 1080628_df_HF
# formed successfully 1080628_df_Stocks
#
# Finished working on  1080628
# #####################
#
# Started working on  1163744
# Started Updating df_details for 1163744
# Done df_details for 1163744
# Started download_files_and_try_read for 1163744
# Done second download 1163744, sum_status is 0
# formed successfully 1163744_df_HF
# formed successfully 1163744_df_Stocks
#
# Finished working on  1163744
# #####################
#
# Started working on  1140804
# Started Updating df_details for 1140804
# couldn't work with  1140804
# #####################
#
# Started working on  1583977
# Started Updating df_details for 1583977
# Done df_details for 1583977
# Started download_files_and_try_read for 1583977
# Done second download 1583977, sum_status is 0
# formed successfully 1583977_df_HF
# formed successfully 1583977_df_Stocks
#
# Finished working on  1583977
# #####################
#
# Started working on  824468
# Started Updating df_details for 824468
# Done df_details for 824468
# Started download_files_and_try_read for 824468
# Done second download 824468, sum_status is 0
# formed successfully 824468_df_HF
# formed successfully 824468_df_Stocks
#
# Finished working on  824468
# #####################
#
# Started working on  1761013
# Started Updating df_details for 1761013
# Done df_details for 1761013
# Started download_files_and_try_read for 1761013
# Done second download 1761013, sum_status is 0
# formed successfully 1761013_df_HF
# formed successfully 1761013_df_Stocks
#
# Finished working on  1761013
# #####################
#
# Started working on  1362535
# Started Updating df_details for 1362535
# Done df_details for 1362535
# Started download_files_and_try_read for 1362535
# Done second download 1362535, sum_status is 0
# formed successfully 1362535_df_HF
# formed successfully 1362535_df_Stocks
#
# Finished working on  1362535
# #####################
#
# Started working on  1009207
# Started Updating df_details for 1009207
# Done df_details for 1009207
# Started download_files_and_try_read for 1009207
# Done second download 1009207, sum_status is 0
# formed successfully 1009207_df_HF
# formed successfully 1009207_df_Stocks
#
# Finished working on  1009207
# #####################
#
# Started working on  1747057
# Started Updating df_details for 1747057
# Done df_details for 1747057
# Started download_files_and_try_read for 1747057
# Done second download 1747057, sum_status is 0
# formed successfully 1747057_df_HF
# formed successfully 1747057_df_Stocks
#
# Finished working on  1747057
# #####################
#
# Started working on  1609098
# Started Updating df_details for 1609098
# Done df_details for 1609098
# Started download_files_and_try_read for 1609098
# Done second download 1609098, sum_status is 0
# formed successfully 1609098_df_HF
# formed successfully 1609098_df_Stocks
#
# Finished working on  1609098
# #####################
#
# Started working on  27135
# Started Updating df_details for 27135
# 27135 doesn't have 13F files
#
# Finished working on  27135
# #####################
#
# Started working on  1595082
# Started Updating df_details for 1595082
# Done df_details for 1595082
# Started download_files_and_try_read for 1595082
# Done second download 1595082, sum_status is 0
# formed successfully 1595082_df_HF
# formed successfully 1595082_df_Stocks
#
# Finished working on  1595082
# #####################
#
# Started working on  1009258
# Started Updating df_details for 1009258
# Done df_details for 1009258
# Started download_files_and_try_read for 1009258
# Done second download 1009258, sum_status is 0
# formed successfully 1009258_df_HF
# formed successfully 1009258_df_Stocks
#
# Finished working on  1009258
# #####################
#
# Started working on  1008894
# Started Updating df_details for 1008894
# Done df_details for 1008894
# Started download_files_and_try_read for 1008894
# Done second download 1008894, sum_status is 0
# formed successfully 1008894_df_HF
# formed successfully 1008894_df_Stocks
#
# Finished working on  1008894
# #####################
#
# Started working on  1217541
# Started Updating df_details for 1217541
# Done df_details for 1217541
# Started download_files_and_try_read for 1217541
# Done second download 1217541, sum_status is 0
# formed successfully 1217541_df_HF
# formed successfully 1217541_df_Stocks
#
# Finished working on  1217541
# #####################
#
# Started working on  354204
# Started Updating df_details for 354204
# Done df_details for 354204
# Started download_files_and_try_read for 354204
# Done second download 354204, sum_status is 0
# formed successfully 354204_df_HF
# formed successfully 354204_df_Stocks
#
# Finished working on  354204
# #####################
#
# Started working on  1050442
# Started Updating df_details for 1050442
# Done df_details for 1050442
# Started download_files_and_try_read for 1050442
# Done second download 1050442, sum_status is 0
# formed successfully 1050442_df_HF
# formed successfully 1050442_df_Stocks
#
# Finished working on  1050442
# #####################
#
# Started working on  1578299
# Started Updating df_details for 1578299
# Done df_details for 1578299
# Started download_files_and_try_read for 1578299
# Done second download 1578299, sum_status is 0
# formed successfully 1578299_df_HF
# formed successfully 1578299_df_Stocks
#
# Finished working on  1578299
# #####################
#
# Started working on  1602189
# Started Updating df_details for 1602189
# Done df_details for 1602189
# Started download_files_and_try_read for 1602189
# Done second download 1602189, sum_status is 0
# formed successfully 1602189_df_HF
# formed successfully 1602189_df_Stocks
#
# Finished working on  1602189
# #####################
#
# Started working on  938206
# Started Updating df_details for 938206
# Done df_details for 938206
# Started download_files_and_try_read for 938206
# Done second download 938206, sum_status is 0
# formed successfully 938206_df_HF
# formed successfully 938206_df_Stocks
#
# Finished working on  938206
# #####################
#
# Started working on  1214639
# Started Updating df_details for 1214639
# Done df_details for 1214639
# Started download_files_and_try_read for 1214639
# Done second download 1214639, sum_status is 0
# formed successfully 1214639_df_HF
# formed successfully 1214639_df_Stocks
#
# Finished working on  1214639
# #####################
#
# Started working on  1798849
# Started Updating df_details for 1798849
# Done df_details for 1798849
# Started download_files_and_try_read for 1798849
# Done second download 1798849, sum_status is 0
# formed successfully 1798849_df_HF
# formed successfully 1798849_df_Stocks
#
# Finished working on  1798849
# #####################
#
# Started working on  790502
# Started Updating df_details for 790502
# Done df_details for 790502
# Started download_files_and_try_read for 790502
# Done second download 790502, sum_status is 0
# formed successfully 790502_df_HF
# formed successfully 790502_df_Stocks
#
# Finished working on  790502
# #####################
#
# Started working on  945631
# Started Updating df_details for 945631
# Done df_details for 945631
# Started download_files_and_try_read for 945631
# Done second download 945631, sum_status is 0
# formed successfully 945631_df_HF
# formed successfully 945631_df_Stocks
#
# Finished working on  945631
# #####################
#
# Started working on  1076598
# Started Updating df_details for 1076598
# Done df_details for 1076598
# Started download_files_and_try_read for 1076598
# Done second download 1076598, sum_status is 0
# formed successfully 1076598_df_HF
# formed successfully 1076598_df_Stocks
#
# Finished working on  1076598
# #####################
#
# Started working on  1352342
# Started Updating df_details for 1352342
# Done df_details for 1352342
# Started download_files_and_try_read for 1352342
# Done second download 1352342, sum_status is 0
# formed successfully 1352342_df_HF
# formed successfully 1352342_df_Stocks
#
# Finished working on  1352342
# #####################
#
# Started working on  1581811
# Started Updating df_details for 1581811
# Done df_details for 1581811
# Started download_files_and_try_read for 1581811
# Done second download 1581811, sum_status is 0
# formed successfully 1581811_df_HF
# formed successfully 1581811_df_Stocks
#
# Finished working on  1581811
# #####################
#
# Started working on  1791786
# Started Updating df_details for 1791786
# Done df_details for 1791786
# Started download_files_and_try_read for 1791786
# Done second download 1791786, sum_status is 0
# formed successfully 1791786_df_HF
# formed successfully 1791786_df_Stocks
#
# Finished working on  1791786
# #####################
#
# Started working on  1107310
# Started Updating df_details for 1107310
# Done df_details for 1107310
# Started download_files_and_try_read for 1107310
# Done second download 1107310, sum_status is 0
# formed successfully 1107310_df_HF
# formed successfully 1107310_df_Stocks
#
# Finished working on  1107310
# #####################
#
# Started working on  1388814
# Started Updating df_details for 1388814
# Done df_details for 1388814
# Started download_files_and_try_read for 1388814
# Done second download 1388814, sum_status is 0
# formed successfully 1388814_df_HF
# formed successfully 1388814_df_Stocks
#
# Finished working on  1388814
# #####################
#
# Started working on  1305841
# Started Updating df_details for 1305841
# Done df_details for 1305841
# Started download_files_and_try_read for 1305841
# Done second download 1305841, sum_status is 0
# formed successfully 1305841_df_HF
# formed successfully 1305841_df_Stocks
#
# Finished working on  1305841
# #####################
#
# Started working on  1736225
# Started Updating df_details for 1736225
# Done df_details for 1736225
# Started download_files_and_try_read for 1736225
# Done second download 1736225, sum_status is 0
# formed successfully 1736225_df_HF
# formed successfully 1736225_df_Stocks
#
# Finished working on  1736225
# #####################
#
# Started working on  909661
# Started Updating df_details for 909661
# Done df_details for 909661
# Started download_files_and_try_read for 909661
# Done second download 909661, sum_status is 0
# formed successfully 909661_df_HF
# formed successfully 909661_df_Stocks
#
# Finished working on  909661
# #####################
#
# Started working on  884566
# Started Updating df_details for 884566
# Done df_details for 884566
# Started download_files_and_try_read for 884566
# Done second download 884566, sum_status is 0
# formed successfully 884566_df_HF
# formed successfully 884566_df_Stocks
#
# Finished working on  884566
# #####################
#
# Started working on  1325447
# Started Updating df_details for 1325447
# Done df_details for 1325447
# Started download_files_and_try_read for 1325447
# Done second download 1325447, sum_status is 0
# formed successfully 1325447_df_HF
# formed successfully 1325447_df_Stocks
#
# Finished working on  1325447
# #####################
#
# Started working on  728083
# Started Updating df_details for 728083
# Done df_details for 728083
# Started download_files_and_try_read for 728083
# Done second download 728083, sum_status is 0
# formed successfully 728083_df_HF
# formed successfully 728083_df_Stocks
#
# Finished working on  728083
# #####################
#
# Started working on  1377581
# Started Updating df_details for 1377581
# Done df_details for 1377581
# Started download_files_and_try_read for 1377581
# Done second download 1377581, sum_status is 0
# formed successfully 1377581_df_HF
# formed successfully 1377581_df_Stocks
#
# Finished working on  1377581
# #####################
#
# Started working on  1418204
# Started Updating df_details for 1418204
# Done df_details for 1418204
# Started download_files_and_try_read for 1418204
# Done second download 1418204, sum_status is 0
# formed successfully 1418204_df_HF
# formed successfully 1418204_df_Stocks
#
# Finished working on  1418204
# #####################
#
# Started working on  850529
# Started Updating df_details for 850529
# Done df_details for 850529
# Started download_files_and_try_read for 850529
# Done second download 850529, sum_status is 0
# formed successfully 850529_df_HF
# formed successfully 850529_df_Stocks
#
# Finished working on  850529
# #####################
#
# Started working on  1009016
# Started Updating df_details for 1009016
# Done df_details for 1009016
# Started download_files_and_try_read for 1009016
# Done second download 1009016, sum_status is 0
# formed successfully 1009016_df_HF
# formed successfully 1009016_df_Stocks
#
# Finished working on  1009016
# #####################
#
# Started working on  1546190
# Started Updating df_details for 1546190
# Done df_details for 1546190
# Started download_files_and_try_read for 1546190
# Done second download 1546190, sum_status is 0
# formed successfully 1546190_df_HF
# formed successfully 1546190_df_Stocks
#
# Finished working on  1546190
# #####################
#
# Started working on  1197853
# Started Updating df_details for 1197853
# Done df_details for 1197853
# Started download_files_and_try_read for 1197853
# Done second download 1197853, sum_status is 0
# formed successfully 1197853_df_HF
# formed successfully 1197853_df_Stocks
#
# Finished working on  1197853
# #####################
#
# Started working on  3520
# Started Updating df_details for 3520
# Done df_details for 3520
# Started download_files_and_try_read for 3520
# Done second download 3520, sum_status is 0
# formed successfully 3520_df_HF
# formed successfully 3520_df_Stocks
#
# Finished working on  3520
# #####################
#
# Started working on  1082327
# Started Updating df_details for 1082327
# Done df_details for 1082327
# Started download_files_and_try_read for 1082327
# Done second download 1082327, sum_status is 0
# formed successfully 1082327_df_HF
# formed successfully 1082327_df_Stocks
#
# Finished working on  1082327
# #####################
#
# Started working on  1569205
# Started Updating df_details for 1569205
# Done df_details for 1569205
# Started download_files_and_try_read for 1569205
# Done second download 1569205, sum_status is 0
# formed successfully 1569205_df_HF
# formed successfully 1569205_df_Stocks
#
# Finished working on  1569205
# #####################
#
# Started working on  1081407
# Started Updating df_details for 1081407
# Done df_details for 1081407
# Started download_files_and_try_read for 1081407
# Done second download 1081407, sum_status is 0
# formed successfully 1081407_df_HF
# formed successfully 1081407_df_Stocks
#
# Finished working on  1081407
# #####################
#
# Started working on  860643
# Started Updating df_details for 860643
# Done df_details for 860643
# Started download_files_and_try_read for 860643
# Done second download 860643, sum_status is 0
# formed successfully 860643_df_HF
# formed successfully 860643_df_Stocks
#
# Finished working on  860643
# #####################
#
# Started working on  1214717
# Started Updating df_details for 1214717
# Done df_details for 1214717
# Started download_files_and_try_read for 1214717
# Done second download 1214717, sum_status is 0
# formed successfully 1214717_df_HF
# formed successfully 1214717_df_Stocks
#
# Finished working on  1214717
# #####################
#
# Started working on  1076809
# Started Updating df_details for 1076809
# Done df_details for 1076809
# Started download_files_and_try_read for 1076809
# Done second download 1076809, sum_status is 0
# formed successfully 1076809_df_HF
# formed successfully 1076809_df_Stocks
#
# Finished working on  1076809
# #####################
#
# Started working on  1138995
# Started Updating df_details for 1138995
# Done df_details for 1138995
# Started download_files_and_try_read for 1138995
# Done second download 1138995, sum_status is 0
# formed successfully 1138995_df_HF
# formed successfully 1138995_df_Stocks
#
# Finished working on  1138995
# #####################
#
# Started working on  1697233
# Started Updating df_details for 1697233
# Done df_details for 1697233
# Started download_files_and_try_read for 1697233
# Done second download 1697233, sum_status is 0
# formed successfully 1697233_df_HF
# formed successfully 1697233_df_Stocks
#
# Finished working on  1697233
# #####################
#
# Started working on  1070039
# Started Updating df_details for 1070039
# 1070039 doesn't have 13F files
#
# Finished working on  1070039
# #####################
#
# Started working on  1078013
# Started Updating df_details for 1078013
# Done df_details for 1078013
# Started download_files_and_try_read for 1078013
# Done second download 1078013, sum_status is 0
# formed successfully 1078013_df_HF
# formed successfully 1078013_df_Stocks
#
# Finished working on  1078013
# #####################
#
# Started working on  846222
# Started Updating df_details for 846222
# Done df_details for 846222
# Started download_files_and_try_read for 846222
# Done second download 846222, sum_status is 0
# formed successfully 846222_df_HF
# formed successfully 846222_df_Stocks
#
# Finished working on  846222
# #####################
#
# Started working on  1840735
# Started Updating df_details for 1840735
# Done df_details for 1840735
# Started download_files_and_try_read for 1840735
# Done second download 1840735, sum_status is 0
# couldn't work with  1840735
# #####################
#
# Started working on  1224324
# Started Updating df_details for 1224324
# Done df_details for 1224324
# Started download_files_and_try_read for 1224324
# Done second download 1224324, sum_status is 0
# formed successfully 1224324_df_HF
# formed successfully 1224324_df_Stocks
#
# Finished working on  1224324
# #####################
#
# Started working on  1082917
# Started Updating df_details for 1082917
# Done df_details for 1082917
# Started download_files_and_try_read for 1082917
# Done second download 1082917, sum_status is 0
# formed successfully 1082917_df_HF
# formed successfully 1082917_df_Stocks
#
# Finished working on  1082917
# #####################
#
# Started working on  928196
# Started Updating df_details for 928196
# Done df_details for 928196
# Started download_files_and_try_read for 928196
# Done second download 928196, sum_status is 0
# formed successfully 928196_df_HF
# formed successfully 928196_df_Stocks
#
# Finished working on  928196
# #####################
#
# Started working on  813917
# Started Updating df_details for 813917
# Done df_details for 813917
# Started download_files_and_try_read for 813917
# Done second download 813917, sum_status is 5
# 813917 Couldn't create df_HF file
#
# Finished working on  813917
# #####################
#
# Started working on  922439
# Started Updating df_details for 922439
# Done df_details for 922439
# Started download_files_and_try_read for 922439
# Done second download 922439, sum_status is 0
# formed successfully 922439_df_HF
# formed successfully 922439_df_Stocks
#
# Finished working on  922439
# #####################
#
# Started working on  1011443
# Started Updating df_details for 1011443
# Done df_details for 1011443
# Started download_files_and_try_read for 1011443
# Done second download 1011443, sum_status is 0
# formed successfully 1011443_df_HF
# formed successfully 1011443_df_Stocks
#
# Finished working on  1011443
# #####################
#
# Started working on  1462245
# Started Updating df_details for 1462245
# Done df_details for 1462245
# Started download_files_and_try_read for 1462245
# Done second download 1462245, sum_status is 0
# formed successfully 1462245_df_HF
# formed successfully 1462245_df_Stocks
#
# Finished working on  1462245
# #####################
#
# Started working on  1510589
# Started Updating df_details for 1510589
# Done df_details for 1510589
# Started download_files_and_try_read for 1510589
# Done second download 1510589, sum_status is 0
# formed successfully 1510589_df_HF
# formed successfully 1510589_df_Stocks
#
# Finished working on  1510589
# #####################
#
# Started working on  1611613
# Started Updating df_details for 1611613
# Done df_details for 1611613
# Started download_files_and_try_read for 1611613
# Done second download 1611613, sum_status is 0
# formed successfully 1611613_df_HF
# formed successfully 1611613_df_Stocks
#
# Finished working on  1611613
# #####################
#
# Started working on  1700574
# Started Updating df_details for 1700574
# Done df_details for 1700574
# Started download_files_and_try_read for 1700574
# Done second download 1700574, sum_status is 0
# formed successfully 1700574_df_HF
# formed successfully 1700574_df_Stocks
#
# Finished working on  1700574
# #####################
#
# Started working on  1504744
# Started Updating df_details for 1504744
# Done df_details for 1504744
# Started download_files_and_try_read for 1504744
# Done second download 1504744, sum_status is 0
# formed successfully 1504744_df_HF
# formed successfully 1504744_df_Stocks
#
# Finished working on  1504744
# #####################
#
# Started working on  1164833
# Started Updating df_details for 1164833
# Done df_details for 1164833
# Started download_files_and_try_read for 1164833
# Done second download 1164833, sum_status is 0
# formed successfully 1164833_df_HF
# formed successfully 1164833_df_Stocks
#
# Finished working on  1164833
# #####################
#
# Started working on  1393825
# Started Updating df_details for 1393825
# Done df_details for 1393825
# Started download_files_and_try_read for 1393825
# Done second download 1393825, sum_status is 0
# formed successfully 1393825_df_HF
# formed successfully 1393825_df_Stocks
#
# Finished working on  1393825
# #####################
#
# Started working on  1569709
# Started Updating df_details for 1569709
# Done df_details for 1569709
# Started download_files_and_try_read for 1569709
# Done second download 1569709, sum_status is 0
# formed successfully 1569709_df_HF
# formed successfully 1569709_df_Stocks
#
# Finished working on  1569709
# #####################
#
# Started working on  1698246
# Started Updating df_details for 1698246
# Done df_details for 1698246
# Started download_files_and_try_read for 1698246
# Done second download 1698246, sum_status is 0
# formed successfully 1698246_df_HF
# formed successfully 1698246_df_Stocks
#
# Finished working on  1698246
# #####################
#
# Started working on  1033427
# Started Updating df_details for 1033427
# Done df_details for 1033427
# Started download_files_and_try_read for 1033427
# Done second download 1033427, sum_status is 0
# formed successfully 1033427_df_HF
# formed successfully 1033427_df_Stocks
#
# Finished working on  1033427
# #####################
#
# Started working on  1721508
# Started Updating df_details for 1721508
# Done df_details for 1721508
# Started download_files_and_try_read for 1721508
# Done second download 1721508, sum_status is 0
# formed successfully 1721508_df_HF
# formed successfully 1721508_df_Stocks
#
# Finished working on  1721508
# #####################
#
# Started working on  1605911
# Started Updating df_details for 1605911
# Done df_details for 1605911
# Started download_files_and_try_read for 1605911
# Done second download 1605911, sum_status is 0
# formed successfully 1605911_df_HF
# formed successfully 1605911_df_Stocks
#
# Finished working on  1605911
# #####################
#
# Started working on  884414
# Started Updating df_details for 884414
# Done df_details for 884414
# Started download_files_and_try_read for 884414
# Done second download 884414, sum_status is 0
# formed successfully 884414_df_HF
# formed successfully 884414_df_Stocks
#
# Finished working on  884414
# #####################
#
# Started working on  53417
# Started Updating df_details for 53417
# Done df_details for 53417
# Started download_files_and_try_read for 53417
# Done second download 53417, sum_status is 0
# formed successfully 53417_df_HF
# formed successfully 53417_df_Stocks
#
# Finished working on  53417
# #####################
#
# Started working on  1525234
# Started Updating df_details for 1525234
# Done df_details for 1525234
# Started download_files_and_try_read for 1525234
# Done second download 1525234, sum_status is 0
# formed successfully 1525234_df_HF
# formed successfully 1525234_df_Stocks
#
# Finished working on  1525234
# #####################
#
# Started working on  884589
# Started Updating df_details for 884589
# Done df_details for 884589
# Started download_files_and_try_read for 884589
# Done second download 884589, sum_status is 0
# formed successfully 884589_df_HF
# formed successfully 884589_df_Stocks
#
# Finished working on  884589
# #####################
#
# Started working on  310051
# Started Updating df_details for 310051
# Done df_details for 310051
# Started download_files_and_try_read for 310051
# Done second download 310051, sum_status is 0
# formed successfully 310051_df_HF
# formed successfully 310051_df_Stocks
#
# Finished working on  310051
# #####################
#
# Started working on  1399770
# Started Updating df_details for 1399770
# Done df_details for 1399770
# Started download_files_and_try_read for 1399770
# Done second download 1399770, sum_status is 0
# formed successfully 1399770_df_HF
# formed successfully 1399770_df_Stocks
#
# Finished working on  1399770
# #####################
#
# Started working on  1665198
# Started Updating df_details for 1665198
# Done df_details for 1665198
# Started download_files_and_try_read for 1665198
# Done second download 1665198, sum_status is 0
# formed successfully 1665198_df_HF
# formed successfully 1665198_df_Stocks
#
# Finished working on  1665198
# #####################
#
# Started working on  1390202
# Started Updating df_details for 1390202
# Done df_details for 1390202
# Started download_files_and_try_read for 1390202
# Done second download 1390202, sum_status is 0
# formed successfully 1390202_df_HF
# formed successfully 1390202_df_Stocks
#
# Finished working on  1390202
# #####################
#
# Started working on  1207017
# Started Updating df_details for 1207017
# Done df_details for 1207017
# Started download_files_and_try_read for 1207017
# Done second download 1207017, sum_status is 0
# formed successfully 1207017_df_HF
# formed successfully 1207017_df_Stocks
#
# Finished working on  1207017
# #####################
#
# Started working on  1175523
# Started Updating df_details for 1175523
# Done df_details for 1175523
# Started download_files_and_try_read for 1175523
# Done second download 1175523, sum_status is 0
# formed successfully 1175523_df_HF
# formed successfully 1175523_df_Stocks
#
# Finished working on  1175523
# #####################
#
# Started working on  1279396
# Started Updating df_details for 1279396
# Done df_details for 1279396
# Started download_files_and_try_read for 1279396
# Done second download 1279396, sum_status is 0
# formed successfully 1279396_df_HF
# formed successfully 1279396_df_Stocks
#
# Finished working on  1279396
# #####################
#
# Started working on  1484150
# Started Updating df_details for 1484150
# Done df_details for 1484150
# Started download_files_and_try_read for 1484150
# Done second download 1484150, sum_status is 0
# formed successfully 1484150_df_HF
# formed successfully 1484150_df_Stocks
#
# Finished working on  1484150
# #####################
#
# Started working on  1061165
# Started Updating df_details for 1061165
# Done df_details for 1061165
# Started download_files_and_try_read for 1061165
# Done second download 1061165, sum_status is 0
# formed successfully 1061165_df_HF
# formed successfully 1061165_df_Stocks
#
# Finished working on  1061165
# #####################
#
# Started working on  1177206
# Started Updating df_details for 1177206
# Done df_details for 1177206
# Started download_files_and_try_read for 1177206
# Done second download 1177206, sum_status is 0
# formed successfully 1177206_df_HF
# formed successfully 1177206_df_Stocks
#
# Finished working on  1177206
# #####################
#
# Started working on  1050470
# Started Updating df_details for 1050470
# Done df_details for 1050470
# Started download_files_and_try_read for 1050470
# Done second download 1050470, sum_status is 0
# formed successfully 1050470_df_HF
# formed successfully 1050470_df_Stocks
#
# Finished working on  1050470
# #####################
#
# Started working on  1316580
# Started Updating df_details for 1316580
# Done df_details for 1316580
# Started download_files_and_try_read for 1316580
# Done second download 1316580, sum_status is 0
# ...
# formed successfully 1654344_df_Stocks
#
# Finished working on  1654344
# #####################
#
# Started working on  1642575
# Started Updating df_details for 1642575
# Done df_details for 1642575
# Started download_files_and_try_read for 1642575
# Done second download 1642575, sum_status is 0
# formed successfully 1642575_df_HF
# formed successfully 1642575_df_Stocks
#
# Finished working on  1642575
# #####################
#
# Started working on  1503174
# Started Updating df_details for 1503174
# Done df_details for 1503174
# Started download_files_and_try_read for 1503174
# Done second download 1503174, sum_status is 0
# formed successfully 1503174_df_HF
# formed successfully 1503174_df_Stocks
#
# Finished working on  1503174
# #####################
#
# Started working on  1517137
# Started Updating df_details for 1517137
# Done df_details for 1517137
# Started download_files_and_try_read for 1517137
# Done second download 1517137, sum_status is 0
# formed successfully 1517137_df_HF
# formed successfully 1517137_df_Stocks
#
# Finished working on  1517137
# #####################
#
# Started working on  1214822
# Started Updating df_details for 1214822
# Done df_details for 1214822
# Started download_files_and_try_read for 1214822
# Done second download 1214822, sum_status is 0
# formed successfully 1214822_df_HF
# formed successfully 1214822_df_Stocks
#
# Finished working on  1214822
# #####################
#
# Started working on  1505183
# Started Updating df_details for 1505183
# Done df_details for 1505183
# Started download_files_and_try_read for 1505183
# Done second download 1505183, sum_status is 0
# formed successfully 1505183_df_HF
# formed successfully 1505183_df_Stocks
#
# Finished working on  1505183
# #####################
#
# Started working on  1569064
# Started Updating df_details for 1569064
# Done df_details for 1569064
# Started download_files_and_try_read for 1569064
# Done second download 1569064, sum_status is 0
# formed successfully 1569064_df_HF
# formed successfully 1569064_df_Stocks
#
# Finished working on  1569064
# #####################
#
# Started working on  1627436
# Started Updating df_details for 1627436
# Done df_details for 1627436
# Started download_files_and_try_read for 1627436
# Done second download 1627436, sum_status is 0
# formed successfully 1627436_df_HF
# formed successfully 1627436_df_Stocks
#
# Finished working on  1627436
# #####################
#
# Started working on  1647251
# Started Updating df_details for 1647251
# Done df_details for 1647251
# Started download_files_and_try_read for 1647251
# Done second download 1647251, sum_status is 0
# formed successfully 1647251_df_HF
# formed successfully 1647251_df_Stocks
#
# Finished working on  1647251
# #####################
#
# Started working on  1346554
# Started Updating df_details for 1346554
# Done df_details for 1346554
# Started download_files_and_try_read for 1346554
# Done second download 1346554, sum_status is 0
# formed successfully 1346554_df_HF
# formed successfully 1346554_df_Stocks
#
# Finished working on  1346554
# #####################
#
# Started working on  1040273
# Started Updating df_details for 1040273
# Done df_details for 1040273
# Started download_files_and_try_read for 1040273
# Done second download 1040273, sum_status is 0
# formed successfully 1040273_df_HF
# formed successfully 1040273_df_Stocks
#
# Finished working on  1040273
# #####################
#
# Started working on  1450701
# Started Updating df_details for 1450701
# Done df_details for 1450701
# Started download_files_and_try_read for 1450701
# Done second download 1450701, sum_status is 0
# formed successfully 1450701_df_HF
# formed successfully 1450701_df_Stocks
#
# Finished working on  1450701
# #####################
#
# Started working on  1008322
# Started Updating df_details for 1008322
# Done df_details for 1008322
# Started download_files_and_try_read for 1008322
# Done second download 1008322, sum_status is 0
# formed successfully 1008322_df_HF
# formed successfully 1008322_df_Stocks
#
# Finished working on  1008322
# #####################
#
# Started working on  1145020
# Started Updating df_details for 1145020
# Done df_details for 1145020
# Started download_files_and_try_read for 1145020
# Done second download 1145020, sum_status is 0
# formed successfully 1145020_df_HF
# formed successfully 1145020_df_Stocks
#
# Finished working on  1145020
# #####################
#
# Started working on  1167483
# Started Updating df_details for 1167483
# Done df_details for 1167483
# Started download_files_and_try_read for 1167483
# Done second download 1167483, sum_status is 0
# formed successfully 1167483_df_HF
# formed successfully 1167483_df_Stocks
#
# Finished working on  1167483
# #####################
#
# Started working on  1313816
# Started Updating df_details for 1313816
# Done df_details for 1313816
# Started download_files_and_try_read for 1313816
# Done second download 1313816, sum_status is 0
# formed successfully 1313816_df_HF
# formed successfully 1313816_df_Stocks
#
# Finished working on  1313816
# #####################
#
# Started working on  883961
# Started Updating df_details for 883961
# Done df_details for 883961
# Started download_files_and_try_read for 883961
# Done second download 883961, sum_status is 0
# formed successfully 883961_df_HF
# formed successfully 883961_df_Stocks
#
# Finished working on  883961
# #####################
#
# Started working on  1280965
# Started Updating df_details for 1280965
# Done df_details for 1280965
# Started download_files_and_try_read for 1280965
# Done second download 1280965, sum_status is 0
# formed successfully 1280965_df_HF
# formed successfully 1280965_df_Stocks
#
# Finished working on  1280965
# #####################
#
# Started working on  1345471
# Started Updating df_details for 1345471
# Done df_details for 1345471
# Started download_files_and_try_read for 1345471
# Done second download 1345471, sum_status is 0
# formed successfully 1345471_df_HF
# formed successfully 1345471_df_Stocks
#
# Finished working on  1345471
# #####################
#
# Started working on  923093
# Started Updating df_details for 923093
# Done df_details for 923093
# Started download_files_and_try_read for 923093
# Done second download 923093, sum_status is 0
# formed successfully 923093_df_HF
# formed successfully 923093_df_Stocks
#
# Finished working on  923093
# #####################
#
# Started working on  1535588
# Started Updating df_details for 1535588
# Done df_details for 1535588
# Started download_files_and_try_read for 1535588
# Done second download 1535588, sum_status is 0
# formed successfully 1535588_df_HF
# formed successfully 1535588_df_Stocks
#
# Finished working on  1535588
# #####################
#
# Started working on  1478735
# Started Updating df_details for 1478735
# Done df_details for 1478735
# Started download_files_and_try_read for 1478735
# Done second download 1478735, sum_status is 0
# formed successfully 1478735_df_HF
# formed successfully 1478735_df_Stocks
#
# Finished working on  1478735
# #####################
#
# Started working on  1179392
# Started Updating df_details for 1179392
# Done df_details for 1179392
# Started download_files_and_try_read for 1179392
# Done second download 1179392, sum_status is 0
# formed successfully 1179392_df_HF
# formed successfully 1179392_df_Stocks
#
# Finished working on  1179392
# #####################
#
# Started working on  1132716
# Started Updating df_details for 1132716
# Done df_details for 1132716
# Started download_files_and_try_read for 1132716
# Done second download 1132716, sum_status is 0
# formed successfully 1132716_df_HF
# formed successfully 1132716_df_Stocks
#
# Finished working on  1132716
# #####################
#
# Started working on  1418814
# Started Updating df_details for 1418814
# Done df_details for 1418814
# Started download_files_and_try_read for 1418814
# Done second download 1418814, sum_status is 0
# formed successfully 1418814_df_HF
# formed successfully 1418814_df_Stocks
#
# Finished working on  1418814
# #####################
#
# Started working on  1541448
# Started Updating df_details for 1541448
# Done df_details for 1541448
# Started download_files_and_try_read for 1541448
# Done second download 1541448, sum_status is 0
# formed successfully 1541448_df_HF
# formed successfully 1541448_df_Stocks
#
# Finished working on  1541448
# #####################
#
# Started working on  1454027
# Started Updating df_details for 1454027
# Done df_details for 1454027
# Started download_files_and_try_read for 1454027
# Done second download 1454027, sum_status is 0
# formed successfully 1454027_df_HF
# formed successfully 1454027_df_Stocks
#
# Finished working on  1454027
# #####################
#
# Started working on  1040188
# Started Updating df_details for 1040188
# Done df_details for 1040188
# Started download_files_and_try_read for 1040188
# Done second download 1040188, sum_status is 0
# formed successfully 1040188_df_HF
# formed successfully 1040188_df_Stocks
#
# Finished working on  1040188
# #####################
#
# Started working on  1103804
# Started Updating df_details for 1103804
# Done df_details for 1103804
# Started download_files_and_try_read for 1103804
# Done second download 1103804, sum_status is 0
# formed successfully 1103804_df_HF
# formed successfully 1103804_df_Stocks
#
# Finished working on  1103804
# #####################
#
# Started working on  1569532
# Started Updating df_details for 1569532
# Done df_details for 1569532
# Started download_files_and_try_read for 1569532
# Done second download 1569532, sum_status is 0
# formed successfully 1569532_df_HF
# formed successfully 1569532_df_Stocks
#
# Finished working on  1569532
# #####################
#
# Started working on  1556921
# Started Updating df_details for 1556921
# Done df_details for 1556921
# Started download_files_and_try_read for 1556921
# Done second download 1556921, sum_status is 0
# formed successfully 1556921_df_HF
# formed successfully 1556921_df_Stocks
#
# Finished working on  1556921
# #####################
#
# Started working on  928633
# Started Updating df_details for 928633
# Done df_details for 928633
# Started download_files_and_try_read for 928633
# Done second download 928633, sum_status is 0
# formed successfully 928633_df_HF
# formed successfully 928633_df_Stocks
#
# Finished working on  928633
# #####################
#
# Started working on  1556785
# Started Updating df_details for 1556785
# Done df_details for 1556785
# Started download_files_and_try_read for 1556785
# Done second download 1556785, sum_status is 0
# formed successfully 1556785_df_HF
# formed successfully 1556785_df_Stocks
#
# Finished working on  1556785
# #####################
#
# Started working on  1331223
# Started Updating df_details for 1331223
# 1331223 doesn't have 13F files
#
# Finished working on  1331223
# #####################
#
# Started working on  1539919
# Started Updating df_details for 1539919
# Done df_details for 1539919
# Started download_files_and_try_read for 1539919
# Done second download 1539919, sum_status is 0
# formed successfully 1539919_df_HF
# formed successfully 1539919_df_Stocks
#
# Finished working on  1539919
# #####################
#
# Started working on  1162870
# Started Updating df_details for 1162870
# Done df_details for 1162870
# Started download_files_and_try_read for 1162870
# Done second download 1162870, sum_status is 0
# formed successfully 1162870_df_HF
# formed successfully 1162870_df_Stocks
#
# Finished working on  1162870
# #####################
#
# Started working on  1061186
# Started Updating df_details for 1061186
# Done df_details for 1061186
# Started download_files_and_try_read for 1061186
# Done second download 1061186, sum_status is 0
# formed successfully 1061186_df_HF
# formed successfully 1061186_df_Stocks
#
# Finished working on  1061186
# #####################
#
# Started working on  1646247
# Started Updating df_details for 1646247
# Done df_details for 1646247
# Started download_files_and_try_read for 1646247
# Done second download 1646247, sum_status is 0
# formed successfully 1646247_df_HF
# formed successfully 1646247_df_Stocks
#
# Finished working on  1646247
# #####################
#
# Started working on  1357550
# Started Updating df_details for 1357550
# Done df_details for 1357550
# Started download_files_and_try_read for 1357550
# Done second download 1357550, sum_status is 0
# formed successfully 1357550_df_HF
# formed successfully 1357550_df_Stocks
#
# Finished working on  1357550
# #####################
#
# Started working on  1388312
# Started Updating df_details for 1388312
# Done df_details for 1388312
# Started download_files_and_try_read for 1388312
# Done second download 1388312, sum_status is 0
# formed successfully 1388312_df_HF
# formed successfully 1388312_df_Stocks
#
# Finished working on  1388312
# #####################
#
# Started working on  902219
# Started Updating df_details for 902219
# Done df_details for 902219
# Started download_files_and_try_read for 902219
# Done second download 902219, sum_status is 30
# 902219 Couldn't create df_HF file
#
# Finished working on  902219
# #####################
#
# Started working on  1177719
# Started Updating df_details for 1177719
# Done df_details for 1177719
# Started download_files_and_try_read for 1177719
# Done second download 1177719, sum_status is 0
# formed successfully 1177719_df_HF
# formed successfully 1177719_df_Stocks
#
# Finished working on  1177719
# #####################
#
# Started working on  1387322
# Started Updating df_details for 1387322
# Done df_details for 1387322
# Started download_files_and_try_read for 1387322
# Done second download 1387322, sum_status is 0
# formed successfully 1387322_df_HF
# formed successfully 1387322_df_Stocks
#
# Finished working on  1387322
# #####################
#
# Started working on  1644956
# Started Updating df_details for 1644956
# Done df_details for 1644956
# Started download_files_and_try_read for 1644956
# Done second download 1644956, sum_status is 0
# formed successfully 1644956_df_HF
# formed successfully 1644956_df_Stocks
#
# Finished working on  1644956
# #####################
#
# Started working on  1788587
# Started Updating df_details for 1788587
# Done df_details for 1788587
# Started download_files_and_try_read for 1788587
# Done second download 1788587, sum_status is 0
# formed successfully 1788587_df_HF
# formed successfully 1788587_df_Stocks
#
# Finished working on  1788587
# #####################
#
# Started working on  1599383
# Started Updating df_details for 1599383
# Done df_details for 1599383
# Started download_files_and_try_read for 1599383
# Done second download 1599383, sum_status is 0
# formed successfully 1599383_df_HF
# formed successfully 1599383_df_Stocks
#
# Finished working on  1599383
# #####################
#
# Started working on  900973
# Started Updating df_details for 900973
# Done df_details for 900973
# Started download_files_and_try_read for 900973
# Done second download 900973, sum_status is 0
# formed successfully 900973_df_HF
# formed successfully 900973_df_Stocks
#
# Finished working on  900973
# #####################
#
# Started working on  1279891
# Started Updating df_details for 1279891
# Done df_details for 1279891
# Started download_files_and_try_read for 1279891
# Done second download 1279891, sum_status is 0
# formed successfully 1279891_df_HF
# formed successfully 1279891_df_Stocks
#
# Finished working on  1279891
# #####################
#
# Started working on  1784547
# Started Updating df_details for 1784547
# Done df_details for 1784547
# Started download_files_and_try_read for 1784547
# Done second download 1784547, sum_status is 0
# formed successfully 1784547_df_HF
# formed successfully 1784547_df_Stocks
#
# Finished working on  1784547
# #####################
#
# Started working on  905567
# Started Updating df_details for 905567
# Done df_details for 905567
# Started download_files_and_try_read for 905567
# Done second download 905567, sum_status is 0
# formed successfully 905567_df_HF
# formed successfully 905567_df_Stocks
#
# Finished working on  905567
# #####################
#
# Started working on  1086483
# Started Updating df_details for 1086483
# Done df_details for 1086483
# Started download_files_and_try_read for 1086483
# Done second download 1086483, sum_status is 0
# formed successfully 1086483_df_HF
# formed successfully 1086483_df_Stocks
#
# Finished working on  1086483
# #####################
#
# Started working on  1565854
# Started Updating df_details for 1565854
# Done df_details for 1565854
# Started download_files_and_try_read for 1565854
# Done second download 1565854, sum_status is 0
# formed successfully 1565854_df_HF
# formed successfully 1565854_df_Stocks
#
# Finished working on  1565854
# #####################
#
# Wall time: 1h 56min 5s

# %%
# %%time
error_list=[]
CIK_Done=[]
for CIK in cik_list: 
    #print("Started working on missing stock files ",CIK)
    
    try: 
        if check_if_stock_file_exists(CIK) is False:
            if get_files_details(CIK) is True:
                if download_files_and_try_read(CIK) is True: 
                    if from_cik_files_to_df(CIK) is True: 
                        print(f"formed successfully {CIK}_df_HF")

                        if create_stocks_df(CIK) is True:
                            print(f"formed successfully {CIK}_df_Stocks")
                        else:
                            print(f"failed to create {CIK}_df_Stocks")
                            error_list.append(CIK)

                    else:
                        print(CIK, "Couldn't create df_HF file")
                        error_list.append(CIK)

                else:
                    error_list.append(CIK)
                    print("Incorrupt files were detected at ",CIK)
                    print("#####################\n ")

            else:
                error_list.append(CIK)
                print(CIK, "doesn't have 13F files")

            print("\nFinished working on ",CIK)
            print("#####################\n ")
        else:
            print("Stock DF was created Successfully", CIK)
            CIK_Done.append(CIK)

    except:
        print("couldn't work with ",CIK)
        error_list.append(CIK)
        print("#####################\n ")
        pass
# Out:
# Stock DF was created Successfully 1539436
# Stock DF was created Successfully 1358706
# Stock DF was created Successfully 916542
# Stock DF was created Successfully 1165408
# Stock DF was created Successfully 1097278
# Stock DF was created Successfully 1112520
# Stock DF was created Successfully 1230239
# Stock DF was created Successfully 1326234
# Stock DF was created Successfully 1109448
# Stock DF was created Successfully 1396835
# Stock DF was created Successfully 1541617
# Stock DF was created Successfully 1453072
# Stock DF was created Successfully 1102598
# Stock DF was created Successfully 1446114
# Stock DF was created Successfully 1323255
# Stock DF was created Successfully 1656456
# Stock DF was created Successfully 1167557
# Stock DF was created Successfully 1608108
# Stock DF was created Successfully 936753
# Stock DF was created Successfully 1080171
# Stock DF was created Successfully 860644
# Stock DF was created Successfully 1697748
# Stock DF was created Successfully 1601086
# Stock DF was created Successfully 1483859
# Stock DF was created Successfully 1164508
# Stock DF was created Successfully 1466153
# Stock DF was created Successfully 700529
# Stock DF was created Successfully 1730574
# Stock DF was created Successfully 1027817
# Stock DF was created Successfully 1777813
# Started Updating df_details for 1221362
# Done df_details for 1221362
# Started download_files_and_try_read for 1221362
# Done second download 1221362, sum_status is 0
# formed successfully 1221362_df_HF
# formed successfully 1221362_df_Stocks
#
# Finished working on  1221362
# #####################
#
# Stock DF was created Successfully 1791827
# Stock DF was created Successfully 1633313
# Stock DF was created Successfully 1109147
# Stock DF was created Successfully 1263508
# Stock DF was created Successfully 1218710
# Stock DF was created Successfully 1340807
# Stock DF was created Successfully 9015
# Stock DF was created Successfully 313028
# Stock DF was created Successfully 1061768
# Stock DF was created Successfully 1711889
# Started Updating df_details for 12518
# 12518 doesn't have 13F files
#
# Finished working on  12518
# #####################
#
# Stock DF was created Successfully 1610880
# Stock DF was created Successfully 1600285
# Stock DF was created Successfully 1386060
# Stock DF was created Successfully 1015086
# Stock DF was created Successfully 829108
# Stock DF was created Successfully 1350694
# Stock DF was created Successfully 1001085
# Stock DF was created Successfully 1315868
# Stock DF was created Successfully 1802881
# Stock DF was created Successfully 1316507
# Stock DF was created Successfully 1352924
# Stock DF was created Successfully 1789779
# Stock DF was created Successfully 1537014
# Stock DF was created Successfully 1279936
# Stock DF was created Successfully 1323645
# Stock DF was created Successfully 895213
# Stock DF was created Successfully 1426196
# Stock DF was created Successfully 1706766
# Stock DF was created Successfully 1033984
# Started Updating df_details for 1525907
# Done df_details for 1525907
# Started download_files_and_try_read for 1525907
# Done second download 1525907, sum_status is 0
# formed successfully 1525907_df_HF
# couldn't work with  1525907
# #####################
#
# Stock DF was created Successfully 1332632
# Stock DF was created Successfully 1094749
# Stock DF was created Successfully 1423053
# Stock DF was created Successfully 1348883
# Stock DF was created Successfully 1135730
# Stock DF was created Successfully 1080628
# Stock DF was created Successfully 1163744
# Started Updating df_details for 1140804
# couldn't work with  1140804
# #####################
#
# Stock DF was created Successfully 1583977
# Stock DF was created Successfully 824468
# Stock DF was created Successfully 1761013
# Stock DF was created Successfully 1362535
# Stock DF was created Successfully 1009207
# Stock DF was created Successfully 1747057
# Stock DF was created Successfully 1609098
# Started Updating df_details for 27135
# 27135 doesn't have 13F files
#
# Finished working on  27135
# #####################
#
# Stock DF was created Successfully 1595082
# Stock DF was created Successfully 1009258
# Stock DF was created Successfully 1008894
# Stock DF was created Successfully 1217541
# Stock DF was created Successfully 354204
# Stock DF was created Successfully 1050442
# Stock DF was created Successfully 1578299
# Stock DF was created Successfully 1602189
# Stock DF was created Successfully 938206
# Stock DF was created Successfully 1214639
# Stock DF was created Successfully 1798849
# Stock DF was created Successfully 790502
# Stock DF was created Successfully 945631
# Stock DF was created Successfully 1076598
# Stock DF was created Successfully 1352342
# Stock DF was created Successfully 1581811
# Stock DF was created Successfully 1791786
# Stock DF was created Successfully 1107310
# Stock DF was created Successfully 1388814
# Stock DF was created Successfully 1305841
# Stock DF was created Successfully 1736225
# Stock DF was created Successfully 909661
# Stock DF was created Successfully 884566
# Stock DF was created Successfully 1325447
# Stock DF was created Successfully 728083
# Stock DF was created Successfully 1377581
# Stock DF was created Successfully 1418204
# Stock DF was created Successfully 850529
# Stock DF was created Successfully 1009016
# Stock DF was created Successfully 1546190
# Stock DF was created Successfully 1197853
# Stock DF was created Successfully 3520
# Stock DF was created Successfully 1082327
# Stock DF was created Successfully 1569205
# Stock DF was created Successfully 1081407
# Stock DF was created Successfully 860643
# Stock DF was created Successfully 1214717
# Stock DF was created Successfully 1076809
# Stock DF was created Successfully 1138995
# Stock DF was created Successfully 1697233
# Started Updating df_details for 1070039
# 1070039 doesn't have 13F files
#
# Finished working on  1070039
# #####################
#
# Stock DF was created Successfully 1078013
# Stock DF was created Successfully 846222
# Started Updating df_details for 1840735
# Done df_details for 1840735
# Started download_files_and_try_read for 1840735
# Done second download 1840735, sum_status is 0
# formed successfully 1840735_df_HF
# couldn't work with  1840735
# #####################
#
# Stock DF was created Successfully 1224324
# Stock DF was created Successfully 1082917
# Stock DF was created Successfully 928196
# Started Updating df_details for 813917
# Done df_details for 813917
# Started download_files_and_try_read for 813917
# Done second download 813917, sum_status is 5
# 813917 Couldn't create df_HF file
#
# Finished working on  813917
# #####################
#
# Stock DF was created Successfully 922439
# Stock DF was created Successfully 1011443
# Stock DF was created Successfully 1462245
# Stock DF was created Successfully 1510589
# Stock DF was created Successfully 1611613
# Stock DF was created Successfully 1700574
# Stock DF was created Successfully 1504744
# Stock DF was created Successfully 1164833
# Stock DF was created Successfully 1393825
# Stock DF was created Successfully 1569709
# Stock DF was created Successfully 1698246
# Stock DF was created Successfully 1033427
# Stock DF was created Successfully 1721508
# Stock DF was created Successfully 1605911
# Stock DF was created Successfully 884414
# Stock DF was created Successfully 53417
# Stock DF was created Successfully 1525234
# Stock DF was created Successfully 884589
# Stock DF was created Successfully 310051
# Stock DF was created Successfully 1399770
# Stock DF was created Successfully 1665198
# Stock DF was created Successfully 1390202
# Stock DF was created Successfully 1207017
# Stock DF was created Successfully 1175523
# Stock DF was created Successfully 1279396
# Stock DF was created Successfully 1484150
# Stock DF was created Successfully 1061165
# Stock DF was created Successfully 1177206
# Stock DF was created Successfully 1050470
# Stock DF was created Successfully 1316580
# Stock DF was created Successfully 1542302
# Started Updating df_details for 922898
# couldn't work with  922898
# #####################
#
# Stock DF was created Successfully 61227
# Stock DF was created Successfully 919859
# Stock DF was created Successfully 1536105
# Stock DF was created Successfully 1352851
# Started Updating df_details for 1040197
# Done df_details for 1040197
# Started download_files_and_try_read for 1040197
# Done second download 1040197, sum_status is 0
# formed successfully 1040197_df_HF
# formed successfully 1040197_df_Stocks
#
# Finished working on  1040197
# #####################
#
# Stock DF was created Successfully 1070134
# Stock DF was created Successfully 1725248
# Stock DF was created Successfully 1512173
# Stock DF was created Successfully 1040592
# Stock DF was created Successfully 1519964
# Stock DF was created Successfully 1325091
# Stock DF was created Successfully 1055966
# Stock DF was created Successfully 936944
# Started Updating df_details for 912938
# Done df_details for 912938
# Started download_files_and_try_read for 912938
# Done second download 912938, sum_status is 15
# 912938 Couldn't create df_HF file
#
# Finished working on  912938
# #####################
#
# Stock DF was created Successfully 1410830
# Stock DF was created Successfully 934639
# Stock DF was created Successfully 1538449
# Stock DF was created Successfully 1628110
# Stock DF was created Successfully 1427119
# Stock DF was created Successfully 1273087
# Stock DF was created Successfully 1135778
# Stock DF was created Successfully 1448574
# Stock DF was created Successfully 1388805
# Stock DF was created Successfully 1480751
# Stock DF was created Successfully 1418329
# Stock DF was created Successfully 1055964
# Stock DF was created Successfully 1521019
# Stock DF was created Successfully 949509
# Stock DF was created Successfully 822581
# Stock DF was created Successfully 1055951
# Stock DF was created Successfully 1656735
# Stock DF was created Successfully 1568788
# Stock DF was created Successfully 1009006
# Stock DF was created Successfully 1103882
# Stock DF was created Successfully 883677
# Stock DF was created Successfully 1051359
# Stock DF was created Successfully 1521001
# Stock DF was created Successfully 932859
# Stock DF was created Successfully 1035674
# Stock DF was created Successfully 1425851
# Stock DF was created Successfully 1224962
# Stock DF was created Successfully 1336528
# Stock DF was created Successfully 1531721
# Stock DF was created Successfully 743127
# Stock DF was created Successfully 1256071
# Stock DF was created Successfully 1603466
# Stock DF was created Successfully 1509842
# Stock DF was created Successfully 1326389
# Stock DF was created Successfully 1034524
# Stock DF was created Successfully 1387508
# Stock DF was created Successfully 898419
# Stock DF was created Successfully 1590144
# Stock DF was created Successfully 1501436
# Stock DF was created Successfully 1346824
# Started Updating df_details for 1110547
# 1110547 doesn't have 13F files
#
# Finished working on  1110547
# #####################
#
# Stock DF was created Successfully 1425738
# Stock DF was created Successfully 1037389
# Stock DF was created Successfully 1112325
# Stock DF was created Successfully 1595725
# Stock DF was created Successfully 1739439
# Stock DF was created Successfully 71259
# Stock DF was created Successfully 1784260
# Stock DF was created Successfully 1512171
# Stock DF was created Successfully 906304
# Stock DF was created Successfully 1493215
# Stock DF was created Successfully 1720792
# Stock DF was created Successfully 1582090
# Stock DF was created Successfully 1421097
# Stock DF was created Successfully 1508097
# Stock DF was created Successfully 1537530
# Stock DF was created Successfully 1665241
# Stock DF was created Successfully 1317583
# Stock DF was created Successfully 1303159
# Stock DF was created Successfully 1054587
# Stock DF was created Successfully 1006378
# Stock DF was created Successfully 1592643
# Stock DF was created Successfully 1443689
# Stock DF was created Successfully 1232395
# Stock DF was created Successfully 1675884
# Stock DF was created Successfully 1680964
# Stock DF was created Successfully 1517857
# Stock DF was created Successfully 807985
# Stock DF was created Successfully 1319998
# Stock DF was created Successfully 1654344
# Stock DF was created Successfully 1642575
# Stock DF was created Successfully 1503174
# Stock DF was created Successfully 1517137
# Stock DF was created Successfully 1214822
# Stock DF was created Successfully 1505183
# Stock DF was created Successfully 1569064
# Stock DF was created Successfully 1627436
# Stock DF was created Successfully 1647251
# Stock DF was created Successfully 1346554
# Stock DF was created Successfully 1040273
# Stock DF was created Successfully 1450701
# Stock DF was created Successfully 1008322
# Stock DF was created Successfully 1145020
# Stock DF was created Successfully 1167483
# Stock DF was created Successfully 1313816
# Stock DF was created Successfully 883961
# Stock DF was created Successfully 1280965
# Stock DF was created Successfully 1345471
# Stock DF was created Successfully 923093
# Stock DF was created Successfully 1535588
# Stock DF was created Successfully 1478735
# Stock DF was created Successfully 1179392
# Stock DF was created Successfully 1132716
# Stock DF was created Successfully 1418814
# Stock DF was created Successfully 1541448
# Stock DF was created Successfully 1454027
# Stock DF was created Successfully 1040188
# Stock DF was created Successfully 1103804
# Stock DF was created Successfully 1569532
# Stock DF was created Successfully 1556921
# Stock DF was created Successfully 928633
# Stock DF was created Successfully 1556785
# Started Updating df_details for 1331223
# 1331223 doesn't have 13F files
#
# Finished working on  1331223
# #####################
#
# Stock DF was created Successfully 1539919
# Stock DF was created Successfully 1162870
# Stock DF was created Successfully 1061186
# Stock DF was created Successfully 1646247
# Stock DF was created Successfully 1357550
# Stock DF was created Successfully 1388312
# Started Updating df_details for 902219
# Done df_details for 902219
# Started download_files_and_try_read for 902219
# Done second download 902219, sum_status is 30
# 902219 Couldn't create df_HF file
#
# Finished working on  902219
# #####################
#
# Stock DF was created Successfully 1177719
# Stock DF was created Successfully 1387322
# Stock DF was created Successfully 1644956
# Stock DF was created Successfully 1788587
# Stock DF was created Successfully 1599383
# Stock DF was created Successfully 900973
# Stock DF was created Successfully 1279891
# Stock DF was created Successfully 1784547
# Stock DF was created Successfully 905567
# Stock DF was created Successfully 1086483
# Stock DF was created Successfully 1565854
# Wall time: 5min 29s

# %%
len(CIK_Done)
# Out:
# 281

# %%
#CIKs that couldn't create for them stock file
error_list
# Out:
# ['12518',
#  '1525907',
#  '1140804',
#  '27135',
#  '1070039',
#  '1840735',
#  '813917',
#  '922898',
#  '912938',
#  '1110547',
#  '1331223',
#  '902219']

# %%
error_list=["1340807","313028","1595082","860643","1112325"]

# %%
error_list1=[]

# %%
# %%time
for CIK in error_list: 
    print("Started working on ",CIK)
    
    try: 
        if get_files_details(CIK) is True:
            if download_files_and_try_read(CIK) is True: 
                if from_cik_files_to_df(CIK) is True: 
                    print(f"formed successfully {CIK}_df_HF")
                    
                    if create_stocks_df(CIK) is True:
                        print(f"formed successfully {CIK}_df_Stocks")
                    else:
                        print(f"failed to create {CIK}_df_Stocks")
                        error_list1.append(CIK)
                        
                else:
                    print(CIK, "Couldn't create df_HF file")
                    error_list1.append(CIK)
                    
            else:
                error_list1.append(CIK)
                print("Incorrupt files were detected at ",CIK)
                print("#####################\n ")
        
        else:
            error_list1.append(CIK)
            print(CIK, "doesn't have 13F files")
            
        print("\nFinished working on ",CIK)
        print("#####################\n ")

    except:
        print("couldn't work with ",CIK)
        error_list1.append(CIK)
        print("#####################\n ")
        pass
# Out:
# Started working on  1340807
# Started Updating df_details for 1340807
# Done df_details for 1340807
# Started download_files_and_try_read for 1340807
# Done second download 1340807, sum_status is 0
# formed successfully 1340807_df_HF
# formed successfully 1340807_df_Stocks
#
# Finished working on  1340807
# #####################
#
# Started working on  313028
# Started Updating df_details for 313028
# Done df_details for 313028
# Started download_files_and_try_read for 313028
# Done second download 313028, sum_status is 0
# formed successfully 313028_df_HF
# formed successfully 313028_df_Stocks
#
# Finished working on  313028
# #####################
#
# Started working on  1595082
# Started Updating df_details for 1595082
# Done df_details for 1595082
# Started download_files_and_try_read for 1595082
# Done second download 1595082, sum_status is 0
# formed successfully 1595082_df_HF
# formed successfully 1595082_df_Stocks
#
# Finished working on  1595082
# #####################
#
# Started working on  860643
# Started Updating df_details for 860643
# Done df_details for 860643
# Started download_files_and_try_read for 860643
# Done second download 860643, sum_status is 0
# formed successfully 860643_df_HF
# formed successfully 860643_df_Stocks
#
# Finished working on  860643
# #####################
#
# Started working on  1112325
# Started Updating df_details for 1112325
# Done df_details for 1112325
# Started download_files_and_try_read for 1112325
# Done second download 1112325, sum_status is 0
# formed successfully 1112325_df_HF
# formed successfully 1112325_df_Stocks
#
# Finished working on  1112325
# #####################
#
# Wall time: 31.5 s
